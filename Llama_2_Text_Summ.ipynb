# %%
# # Natural Language Processing
# !pip install langchain==0.0.191
# !pip install llama-cpp-python==0.1.66
# !pip install sentence-transformers
# !pip install huggingface_hub
# !pip install auto-gptq==0.2.2
# !pip install termcolor

# %%
GREEN = '\033[92m'
END_COLOR = '\033[0m'

try:
    imported_modules = [
        ("logging", logging),
        ("click", click),
        ("torch", torch),
        ("transformers", transformers),
        ("os", os),
        ("re", re),
        ("shutil", shutil),
        ("subprocess", subprocess),
        ("requests", requests),
        ("pathlib", Path),
        ("auto_gptq", AutoGPTQForCausalLM),
        ("huggingface_hub", hf_hub_download),
        ("huggingface_instruct_embeddings", HuggingFaceInstructEmbeddings),
        ("langchain_pipeline", HuggingFacePipeline),
        ("llama_cpp", LlamaCpp),
        ("prompt_template", PromptTemplate),
        ("llm_chain", LLMChain),
        ("transformers_auto_tokenizer", AutoTokenizer),
        ("transformers_auto_model", AutoModelForCausalLM),
        ("transformers_generation_config", GenerationConfig),
        ("transformers_llm_model", LlamaForCausalLM),
        ("transformers_llm_tokenizer", LlamaTokenizer),
        ("transformers_longformer_tokenizer", LongformerTokenizer), 
        ("transformers_pipeline", pipeline),
        ("rouge", Rouge), 
        ("text_splitter", RecursiveCharacterTextSplitter),
        ("tqdm", tqdm), 
        ("termcolor_colored", colored),
    ]

    print("Module(s) Imported:")
    for module_name, module in imported_modules:
        if module:
            print(f" - {module_name}")

            version = getattr(module, "__version__", None)
            if version:
                print(f"   Version: {GREEN}{version}{END_COLOR}")
except ImportError as e:
    print(f"Failed to import a module: {e}")
# Out:
# Module(s) Imported:
#  - logging
#    Version: 0.5.1.2
#  - click
#    Version: 8.1.7
#  - torch
#    Version: 2.0.1
#  - transformers
#    Version: 4.33.0
#  - os
#  - re
#    Version: 2.2.1
#  - shutil
#  - subprocess
#  - requests
#    Version: 2.31.0
#  - pathlib
#  - auto_gptq
#  - huggingface_hub
#  - huggingface_instruct_embeddings
#  - langchain_pipeline
#  - llama_cpp
#  - prompt_template
#  - llm_chain
#  - transformers_auto_tokenizer
#  - transformers_auto_model
#  - transformers_generation_config
#  - transformers_llm_model
#  - transformers_llm_tokenizer
#  - transformers_longformer_tokenizer
#  - transformers_pipeline
#  - rouge
#  - text_splitter
#  - tqdm
#  - termcolor_colored

# %%
def load_model(device_type, model_id, model_basename=None):

    logging.info(f"Loading Model: {model_id}, on: {device_type}")
    logging.info("This action can take a few minutes!")

    if model_basename is not None:
        if ".ggml" in model_basename:
            logging.info("Using Llamacpp for GGML quantized models")
            model_path = hf_hub_download(repo_id=model_id, filename=model_basename)
            max_ctx_size = 4096
            kwargs = {
                "model_path": model_path,
                "n_ctx": max_ctx_size,
                "max_tokens": max_ctx_size,
            }
            if device_type.lower() == "mps":
                kwargs["n_gpu_layers"] = 1000
            if device_type.lower() == "cuda":
                kwargs["n_gpu_layers"] = 1000
                kwargs["n_batch"] = max_ctx_size
            return LlamaCpp(**kwargs)

        else:
            logging.info("Using AutoGPTQForCausalLM for quantized models")

            if ".safetensors" in model_basename:
                # Remove the ".safetensors" ending if present
                model_basename = model_basename.replace(".safetensors", "")

            tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=True)
            logging.info("Tokenizer loaded")

            model = AutoGPTQForCausalLM.from_quantized(
                model_id,
                model_basename=model_basename,
                use_safetensors=True,
                trust_remote_code=True,
                device="cuda:0",
                use_triton=False,
                quantize_config=None,
            )
    elif (
        device_type.lower() == "cuda"
    ):  
        logging.info("Using AutoModelForCausalLM for full models")
        tokenizer = AutoTokenizer.from_pretrained(model_id)
        logging.info("Tokenizer loaded")

        model = AutoModelForCausalLM.from_pretrained(
            model_id,
            device_map="auto",
            torch_dtype=torch.float16,
            low_cpu_mem_usage=True,
            trust_remote_code=True,
            # max_memory={0: "15GB"} # Uncomment this line with you encounter CUDA out of memory errors
        )
        model.tie_weights()
    else:
        logging.info("Using LlamaTokenizer")
        tokenizer = LlamaTokenizer.from_pretrained(model_id)
        model = LlamaForCausalLM.from_pretrained(model_id)

    generation_config = GenerationConfig.from_pretrained(model_id)

    # Create a pipeline for text generation
    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_length=2048,
        temperature=0,
        top_p=0.95,
        repetition_penalty=1.15,
        generation_config=generation_config,
    )

    local_llm = HuggingFacePipeline(pipeline=pipe)
    logging.info("Local LLM Loaded")

    return local_llm

# %%
DEVICE_TYPE = "cuda" if torch.cuda.is_available() else "cpu"
SHOW_SOURCES = True
logging.info(f"Running on: {DEVICE_TYPE}")
logging.info(f"Display Source Documents set to: {SHOW_SOURCES}")

# %%
model_id = "TheBloke/Llama-2-7B-Chat-GGML"
model_basename = "llama-2-7b-chat.ggmlv3.q4_0.bin"

# %%
LLM = load_model(device_type=DEVICE_TYPE, model_id=model_id, model_basename=model_basename)
# Out:
# llama.cpp: loading model from /Users/tushitdave/.cache/huggingface/hub/models--TheBloke--Llama-2-7B-Chat-GGML/snapshots/00109c56c85ca9015795ca06c272cbc65c7f1dbf/llama-2-7b-chat.ggmlv3.q4_0.bin
# llama_model_load_internal: format     = ggjt v3 (latest)
# llama_model_load_internal: n_vocab    = 32000
# llama_model_load_internal: n_ctx      = 4096
# llama_model_load_internal: n_embd     = 4096
# llama_model_load_internal: n_mult     = 256
# llama_model_load_internal: n_head     = 32
# llama_model_load_internal: n_layer    = 32
# llama_model_load_internal: n_rot      = 128
# llama_model_load_internal: ftype      = 2 (mostly Q4_0)
# llama_model_load_internal: n_ff       = 11008
# llama_model_load_internal: n_parts    = 1
# llama_model_load_internal: model size = 7B
# llama_model_load_internal: ggml ctx size =    0.07 MB
# llama_model_load_internal: mem required  = 5407.71 MB (+ 1026.00 MB per state)
# llama_new_context_with_model: kv self size  = 2048.00 MB
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | VSX = 0 |

# %%
tokenizer = LongformerTokenizer.from_pretrained("allenai/longformer-base-4096")

def fetch_and_save_wiki_text(title):
    response = requests.get(
        "https://en.wikipedia.org/w/api.php",
        params={
            "action": "query",
            "format": "json",
            "titles": title,
            "prop": "extracts",
            "explaintext": True,
        },
    ).json()
    
    page = next(iter(response["query"]["pages"].values()))
    wiki_text = page["extract"]
    
    return wiki_text

def clean_text(text):
    # Remove special characters except "."
    text = re.sub(r'[^A-Za-z0-9\s.\(\)\[\]\{\}]+', '', text)
    # Convert to lowercase
    text = text.lower()
    # Remove extra whitespace
    text = ' '.join(text.split())
    return text

def count_tokens(text):
    tokens = tokenizer.encode(text, add_special_tokens=True)
    return len(tokens)

# %%
wonders_cities = [
    'Beirut',
    'Doha',
    'Durban',
    'Havana',
    'Kuala Lumpur',
    'La Paz',
    'Vigan',
]

data = []
for wonder_city in wonders_cities:
    info = fetch_and_save_wiki_text(wonder_city)
    tokens = tokenizer.encode(info, add_special_tokens=True, truncation=True, max_length=30000)
    num_tokens = len(tokens)
    data.append([wonder_city, info, num_tokens])

df = pd.DataFrame(data, columns=["wonder_city", "information", "num_tokens"])


# df.to_csv("wonder_city_information.csv", index=False)

# %%
df.head()
# Out:
#     wonder_city                                        information  num_tokens
# 0        Beirut  Beirut is the capital and largest city  of  Le...       12695
# 1          Doha  Doha (Arabic: الدوحة, romanized: ad-Dawḥa [adˈ...        9016
# 2        Durban  Durban ( DUR-bən) (Zulu: eThekwini, from ithek...        7992
# 3        Havana  Havana (; Spanish: La Habana [la aˈβana] ; Luc...       30000
# 4  Kuala Lumpur  Kuala Lumpur (Malaysian pronunciation: [ˈkualə...       12584

# %%
df["cleaned_information"] = df["information"].apply(clean_text)
df["token_count"] = df["cleaned_information"].apply(count_tokens)
df.head()
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (12121 > 4096). Running this sequence through the model will result in indexing errors
#     wonder_city                                        information  \
# 0        Beirut  Beirut is the capital and largest city  of  Le...
# 1          Doha  Doha (Arabic: الدوحة, romanized: ad-Dawḥa [adˈ...
# 2        Durban  Durban ( DUR-bən) (Zulu: eThekwini, from ithek...
# 3        Havana  Havana (; Spanish: La Habana [la aˈβana] ; Luc...
# 4  Kuala Lumpur  Kuala Lumpur (Malaysian pronunciation: [ˈkualə...
#
#    num_tokens                                cleaned_information  token_count
# 0       12695  beirut is the capital and largest city of leba...        12121
# 1        9016  doha (arabic romanized addawa [addua] or adda)...         8252
# 2        7992  durban ( durbn) (zulu ethekwini from itheku me...         7395
# 3       30000  havana ( spanish la habana [la aana] lucumi il...        28979
# 4       12584  kuala lumpur (malaysian pronunciation [kual a ...        12397

# %%
df['cleaned_information'][1]
# Out:
# 'doha (arabic romanized addawa [addua] or adda) is the capital city and main financial hub of qatar. located on the persian gulf coast in the east of the country north of al wakrah and south of al khur it is home to most of the countrys population. it is also qatars fastest growing city with over 80 of the nations population living in doha or its surrounding suburbs.doha was founded in the 1820s as an offshoot of al bidda. it was officially declared as the countrys capital in 1971 when qatar gained independence from being a british protectorate. as the commercial capital of qatar and one of the emergent financial centers in the middle east doha is considered a betalevel global city by the globalization and world cities research network. doha accommodates education city an area devoted to research and education and hamad medical city an administrative area of medical care. it also includes doha sports city or aspire zone an international sports destination that includes khalifa international stadium hamad aquatic centre and the aspire dome. the city was host to the first ministeriallevel meeting of the doha development round of world trade organization negotiations. it was also selected as host city of a number of sporting events including the 2006 asian games the 2011 pan arab games the 2019 world beach games the fina world aquatics championships the fivb volleyball club world championship the wta finals and most of the games at the 2011 afc asian cup. in december 2011 the world petroleum council held the 20th world petroleum conference in doha. additionally the city hosted the 2012 unfccc climate negotiations and the 2022 fifa world cup. the city will host the 2027 fiba basketball world cup. the city also hosted the 140th interparliamentary union assembly in april 2019 and hosted 18th yearly session united nations framework convention on climate change in 2012. etymology according to the ministry of municipality and environment of doha the name doha originated from the arabic term dohat meaning roundnessa reference to the rounded bays surrounding the areas coastline. history establishment of al bidda the city of doha was formed seceding from another local settlement known as al bidda. the earliest documented mention of al bidda was made in 1681 by the carmelite convent in an account which chronicles several settlements in qatar. in the record the ruler and a fort in the confines of al bidda are alluded to. carsten niebuhr a german explorer who visited the arabian peninsula created one of the first maps to depict the settlement in 1765 in which he labelled it as guttur.david seaton a british political resident in muscat wrote the first english record of al bidda in 1801. he refers to the town as bedih and describes the geography and defensive structures in the area. he stated that the town had recently been settled by the sudan tribe (singular alsuwaidi) whom he considered to be pirates. seaton attempted to bombard the town with his warship but returned to muscat upon finding that the waters were too shallow to position his warship within striking distance.in 1820 british surveyor r. h. colebrook who visited al bidda remarked on the recent depopulation of the town. he wrote guttur or ul budee [albidda] once a considerable town is protected by two square ghurries [forts] near the seashore but containing no freshwater they are incapable of defense except against sudden incursions of bedouins another ghurry is situated two miles inland and has fresh water with it. this could contain two hundred men. there are remaining at ul budee about 250 men but the original inhabitants who may be expected to return from bahrein will augment them to 900 or 1000 men and if the doasir tribe who frequent the place as divers again settle in it from 600 to 800 men. the same year an agreement known as the general maritime treaty was signed between the east india company and the sheikhs of several persian gulf settlements (some of which were later kn ...

# %%
def generate_summary(text_chunk):
    # Defining the template to generate summary
    template = """
    Write a concise summary of the text, return your responses with 5 lines that cover the key points of the text.
    ```{text}```
    SUMMARY:
    """
    prompt = PromptTemplate(template=template, input_variables=["text"])
    llm_chain = LLMChain(prompt=prompt, llm=LLM)

    summary = llm_chain.run(text_chunk)
    return summary

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=4096, chunk_overlap=50, length_function=len)

df["summary"] = ""

for index, row in tqdm(df.iterrows(), total=len(df), desc="Generating Summaries"):
    wonder_city = row["wonder_city"]
    text_chunk = row["cleaned_information"]
    chunks = text_splitter.split_text(text_chunk)
    chunk_summaries = []

    for chunk in chunks:
        summary = generate_summary(chunk)
        chunk_summaries.append(summary)
    

    combined_summary = "\n".join(chunk_summaries)
    df.at[index, "summary"] = combined_summary
# Out:
# Generating Summaries:   0%|                                                                                      | 0/7 [00:00<?, ?it/s]Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   187.38 ms /   174 runs   (    1.08 ms per token,   928.61 tokens per second)
# llama_print_timings: prompt eval time = 76841.65 ms /  1082 tokens (   71.02 ms per token,    14.08 tokens per second)
# llama_print_timings:        eval time = 18906.01 ms /   173 runs   (  109.28 ms per token,     9.15 tokens per second)
# llama_print_timings:       total time = 96469.14 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   226.86 ms /   240 runs   (    0.95 ms per token,  1057.94 tokens per second)
# llama_print_timings: prompt eval time = 153415.90 ms /  1035 tokens (  148.23 ms per token,     6.75 tokens per second)
# llama_print_timings:        eval time = 23906.07 ms /   239 runs   (  100.03 ms per token,    10.00 tokens per second)
# llama_print_timings:       total time = 178193.92 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   331.15 ms /   271 runs   (    1.22 ms per token,   818.36 tokens per second)
# llama_print_timings: prompt eval time = 96232.10 ms /  1109 tokens (   86.77 ms per token,    11.52 tokens per second)
# llama_print_timings:        eval time = 33595.54 ms /   270 runs   (  124.43 ms per token,     8.04 tokens per second)
# llama_print_timings:       total time = 131039.63 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   325.10 ms /   263 runs   (    1.24 ms per token,   808.99 tokens per second)
# llama_print_timings: prompt eval time = 95003.30 ms /  1008 tokens (   94.25 ms per token,    10.61 tokens per second)
# llama_print_timings:        eval time = 33637.75 ms /   262 runs   (  128.39 ms per token,     7.79 tokens per second)
# llama_print_timings:       total time = 129834.18 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   246.59 ms /   198 runs   (    1.25 ms per token,   802.94 tokens per second)
# llama_print_timings: prompt eval time = 99366.89 ms /  1056 tokens (   94.10 ms per token,    10.63 tokens per second)
# llama_print_timings:        eval time = 24299.02 ms /   198 runs   (  122.72 ms per token,     8.15 tokens per second)
# llama_print_timings:       total time = 124644.30 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   230.75 ms /   185 runs   (    1.25 ms per token,   801.72 tokens per second)
# llama_print_timings: prompt eval time = 97604.25 ms /  1038 tokens (   94.03 ms per token,    10.63 tokens per second)
# llama_print_timings:        eval time = 22509.34 ms /   184 runs   (  122.33 ms per token,     8.17 tokens per second)
# llama_print_timings:       total time = 121036.33 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   280.11 ms /   214 runs   (    1.31 ms per token,   763.99 tokens per second)
# llama_print_timings: prompt eval time = 93142.38 ms /   984 tokens (   94.66 ms per token,    10.56 tokens per second)
# llama_print_timings:        eval time = 26923.98 ms /   213 runs   (  126.40 ms per token,     7.91 tokens per second)
# llama_print_timings:       total time = 121125.77 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   230.13 ms /   215 runs   (    1.07 ms per token,   934.26 tokens per second)
# llama_print_timings: prompt eval time = 130422.29 ms /   919 tokens (  141.92 ms per token,     7.05 tokens per second)
# llama_print_timings:        eval time = 23413.03 ms /   214 runs   (  109.41 ms per token,     9.14 tokens per second)
# llama_print_timings:       total time = 154737.25 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   243.14 ms /   196 runs   (    1.24 ms per token,   806.11 tokens per second)
# llama_print_timings: prompt eval time = 89017.38 ms /   976 tokens (   91.21 ms per token,    10.96 tokens per second)
# llama_print_timings:        eval time = 23782.24 ms /   195 runs   (  121.96 ms per token,     8.20 tokens per second)
# llama_print_timings:       total time = 113750.11 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   315.29 ms /   196 runs   (    1.61 ms per token,   621.64 tokens per second)
# llama_print_timings: prompt eval time = 103959.16 ms /  1051 tokens (   98.91 ms per token,    10.11 tokens per second)
# llama_print_timings:        eval time = 47175.35 ms /   195 runs   (  241.92 ms per token,     4.13 tokens per second)
# llama_print_timings:       total time = 152320.94 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   343.89 ms /   257 runs   (    1.34 ms per token,   747.34 tokens per second)
# llama_print_timings: prompt eval time = 83659.12 ms /   968 tokens (   86.42 ms per token,    11.57 tokens per second)
# llama_print_timings:        eval time = 32780.22 ms /   256 runs   (  128.05 ms per token,     7.81 tokens per second)
# llama_print_timings:       total time = 117676.06 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   341.10 ms /   281 runs   (    1.21 ms per token,   823.80 tokens per second)
# llama_print_timings: prompt eval time = 121776.47 ms /  1010 tokens (  120.57 ms per token,     8.29 tokens per second)
# llama_print_timings:        eval time = 33707.87 ms /   280 runs   (  120.39 ms per token,     8.31 tokens per second)
# llama_print_timings:       total time = 156736.37 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   371.87 ms /   222 runs   (    1.68 ms per token,   596.98 tokens per second)
# llama_print_timings: prompt eval time = 117370.49 ms /  1155 tokens (  101.62 ms per token,     9.84 tokens per second)
# llama_print_timings:        eval time = 35029.37 ms /   221 runs   (  158.50 ms per token,     6.31 tokens per second)
# llama_print_timings:       total time = 153788.01 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   764.00 ms /   434 runs   (    1.76 ms per token,   568.07 tokens per second)
# Generating Summaries:  14%|██████████▌                                                               | 1/7 [32:10<3:13:00, 1930.15s/it]llama_print_timings: prompt eval time = 105359.50 ms /   928 tokens (  113.53 ms per token,     8.81 tokens per second)
# llama_print_timings:        eval time = 70834.96 ms /   434 runs   (  163.21 ms per token,     6.13 tokens per second)
# llama_print_timings:       total time = 178737.66 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   331.75 ms /   195 runs   (    1.70 ms per token,   587.80 tokens per second)
# llama_print_timings: prompt eval time = 119706.07 ms /  1030 tokens (  116.22 ms per token,     8.60 tokens per second)
# llama_print_timings:        eval time = 30879.51 ms /   194 runs   (  159.17 ms per token,     6.28 tokens per second)
# llama_print_timings:       total time = 151854.20 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   230.03 ms /   279 runs   (    0.82 ms per token,  1212.90 tokens per second)
# llama_print_timings: prompt eval time = 750263.07 ms /  1085 tokens (  691.49 ms per token,     1.45 tokens per second)
# llama_print_timings:        eval time = 26729.44 ms /   278 runs   (   96.15 ms per token,    10.40 tokens per second)
# llama_print_timings:       total time = 777970.42 ms
# Llama.generate: prefix-match hit
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   366.07 ms /   319 runs   (    1.15 ms per token,   871.42 tokens per second)
# llama_print_timings: prompt eval time = 85324.90 ms /  1067 tokens (   79.97 ms per token,    12.51 tokens per second)
# llama_print_timings:        eval time = 36595.52 ms /   318 runs   (  115.08 ms per token,     8.69 tokens per second)
# llama_print_timings:       total time = 123244.24 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   209.76 ms /   175 runs   (    1.20 ms per token,   834.28 tokens per second)
# llama_print_timings: prompt eval time = 96120.74 ms /  1069 tokens (   89.92 ms per token,    11.12 tokens per second)
# llama_print_timings:        eval time = 20635.90 ms /   174 runs   (  118.60 ms per token,     8.43 tokens per second)
# llama_print_timings:       total time = 117640.45 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   212.18 ms /   171 runs   (    1.24 ms per token,   805.91 tokens per second)
# llama_print_timings: prompt eval time = 93947.56 ms /  1024 tokens (   91.75 ms per token,    10.90 tokens per second)
# llama_print_timings:        eval time = 20427.23 ms /   170 runs   (  120.16 ms per token,     8.32 tokens per second)
# llama_print_timings:       total time = 115250.60 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =    50.35 ms /    40 runs   (    1.26 ms per token,   794.45 tokens per second)
# llama_print_timings: prompt eval time = 92702.62 ms /   997 tokens (   92.98 ms per token,    10.75 tokens per second)
# llama_print_timings:        eval time =  4659.77 ms /    39 runs   (  119.48 ms per token,     8.37 tokens per second)
# llama_print_timings:       total time = 97758.03 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   164.52 ms /   233 runs   (    0.71 ms per token,  1416.21 tokens per second)
# llama_print_timings: prompt eval time = 1016406.39 ms /   995 tokens ( 1021.51 ms per token,     0.98 tokens per second)
# llama_print_timings:        eval time = 746862.84 ms /   232 runs   ( 3219.24 ms per token,     0.31 tokens per second)
# llama_print_timings:       total time = 1763999.24 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   194.59 ms /   196 runs   (    0.99 ms per token,  1007.27 tokens per second)
# llama_print_timings: prompt eval time = 69057.21 ms /   996 tokens (   69.33 ms per token,    14.42 tokens per second)
# llama_print_timings:        eval time = 20014.94 ms /   195 runs   (  102.64 ms per token,     9.74 tokens per second)
# llama_print_timings:       total time = 89831.60 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   242.56 ms /   214 runs   (    1.13 ms per token,   882.27 tokens per second)
# llama_print_timings: prompt eval time = 89598.46 ms /  1085 tokens (   82.58 ms per token,    12.11 tokens per second)
# llama_print_timings:        eval time = 24309.40 ms /   213 runs   (  114.13 ms per token,     8.76 tokens per second)
# llama_print_timings:       total time = 114863.41 ms
# Llama.generate: prefix-match hit
# Generating Summaries:  29%|████████████████████▌                                                   | 2/7 [1:29:15<3:54:08, 2809.69s/it]
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   213.29 ms /   182 runs   (    1.17 ms per token,   853.28 tokens per second)
# llama_print_timings: prompt eval time = 50276.85 ms /   574 tokens (   87.59 ms per token,    11.42 tokens per second)
# llama_print_timings:        eval time = 19355.82 ms /   181 runs   (  106.94 ms per token,     9.35 tokens per second)
# llama_print_timings:       total time = 70398.35 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   238.29 ms /   198 runs   (    1.20 ms per token,   830.92 tokens per second)
# llama_print_timings: prompt eval time = 98890.08 ms /  1055 tokens (   93.73 ms per token,    10.67 tokens per second)
# llama_print_timings:        eval time = 23630.29 ms /   197 runs   (  119.95 ms per token,     8.34 tokens per second)
# llama_print_timings:       total time = 123479.26 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   437.37 ms /   347 runs   (    1.26 ms per token,   793.38 tokens per second)
# llama_print_timings: prompt eval time = 106718.85 ms /  1128 tokens (   94.61 ms per token,    10.57 tokens per second)
# llama_print_timings:        eval time = 44235.15 ms /   347 runs   (  127.48 ms per token,     7.84 tokens per second)
# llama_print_timings:       total time = 152551.42 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   221.09 ms /   178 runs   (    1.24 ms per token,   805.11 tokens per second)
# llama_print_timings: prompt eval time = 100206.95 ms /  1062 tokens (   94.36 ms per token,    10.60 tokens per second)
# llama_print_timings:        eval time = 22241.31 ms /   177 runs   (  125.66 ms per token,     7.96 tokens per second)
# llama_print_timings:       total time = 123366.87 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   278.62 ms /   216 runs   (    1.29 ms per token,   775.26 tokens per second)
# llama_print_timings: prompt eval time = 99386.73 ms /  1037 tokens (   95.84 ms per token,    10.43 tokens per second)
# llama_print_timings:        eval time = 27306.26 ms /   215 runs   (  127.01 ms per token,     7.87 tokens per second)
# llama_print_timings:       total time = 127769.37 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   207.54 ms /   162 runs   (    1.28 ms per token,   780.56 tokens per second)
# llama_print_timings: prompt eval time = 104480.79 ms /  1078 tokens (   96.92 ms per token,    10.32 tokens per second)
# llama_print_timings:        eval time = 20438.23 ms /   161 runs   (  126.95 ms per token,     7.88 tokens per second)
# llama_print_timings:       total time = 125805.33 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   261.29 ms /   203 runs   (    1.29 ms per token,   776.93 tokens per second)
# llama_print_timings: prompt eval time = 97575.98 ms /  1022 tokens (   95.48 ms per token,    10.47 tokens per second)
# llama_print_timings:        eval time = 25218.45 ms /   202 runs   (  124.84 ms per token,     8.01 tokens per second)
# llama_print_timings:       total time = 123824.31 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   459.42 ms /   325 runs   (    1.41 ms per token,   707.41 tokens per second)
# llama_print_timings: prompt eval time = 90593.98 ms /   938 tokens (   96.58 ms per token,    10.35 tokens per second)
# llama_print_timings:        eval time = 44283.60 ms /   324 runs   (  136.68 ms per token,     7.32 tokens per second)
# llama_print_timings:       total time = 136486.96 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   514.67 ms /   305 runs   (    1.69 ms per token,   592.62 tokens per second)
# llama_print_timings: prompt eval time = 105612.54 ms /   994 tokens (  106.25 ms per token,     9.41 tokens per second)
# llama_print_timings:        eval time = 51615.99 ms /   304 runs   (  169.79 ms per token,     5.89 tokens per second)
# llama_print_timings:       total time = 159032.66 ms
# Llama.generate: prefix-match hit
# Generating Summaries:  43%|██████████████████████████████▊                                         | 3/7 [1:49:25<2:18:36, 2079.10s/it]
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   867.12 ms /   468 runs   (    1.85 ms per token,   539.72 tokens per second)
# llama_print_timings: prompt eval time = 53961.49 ms /   442 tokens (  122.08 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time = 80635.56 ms /   467 runs   (  172.67 ms per token,     5.79 tokens per second)
# llama_print_timings:       total time = 137340.92 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   572.20 ms /   309 runs   (    1.85 ms per token,   540.02 tokens per second)
# llama_print_timings: prompt eval time = 128917.60 ms /  1039 tokens (  124.08 ms per token,     8.06 tokens per second)
# llama_print_timings:        eval time = 54702.03 ms /   308 runs   (  177.60 ms per token,     5.63 tokens per second)
# llama_print_timings:       total time = 185621.72 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   456.44 ms /   231 runs   (    1.98 ms per token,   506.09 tokens per second)
# llama_print_timings: prompt eval time = 129284.99 ms /   999 tokens (  129.41 ms per token,     7.73 tokens per second)
# llama_print_timings:        eval time = 45101.09 ms /   230 runs   (  196.09 ms per token,     5.10 tokens per second)
# llama_print_timings:       total time = 176047.28 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   445.56 ms /   232 runs   (    1.92 ms per token,   520.69 tokens per second)
# llama_print_timings: prompt eval time = 134594.07 ms /  1030 tokens (  130.67 ms per token,     7.65 tokens per second)
# llama_print_timings:        eval time = 41522.93 ms /   231 runs   (  179.75 ms per token,     5.56 tokens per second)
# llama_print_timings:       total time = 177762.77 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   474.89 ms /   245 runs   (    1.94 ms per token,   515.91 tokens per second)
# llama_print_timings: prompt eval time = 120908.81 ms /   963 tokens (  125.55 ms per token,     7.96 tokens per second)
# llama_print_timings:        eval time = 43866.74 ms /   244 runs   (  179.78 ms per token,     5.56 tokens per second)
# llama_print_timings:       total time = 166475.71 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   322.94 ms /   184 runs   (    1.76 ms per token,   569.77 tokens per second)
# llama_print_timings: prompt eval time = 116910.17 ms /   950 tokens (  123.06 ms per token,     8.13 tokens per second)
# llama_print_timings:        eval time = 29221.94 ms /   183 runs   (  159.68 ms per token,     6.26 tokens per second)
# llama_print_timings:       total time = 147382.48 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   302.06 ms /   177 runs   (    1.71 ms per token,   585.98 tokens per second)
# llama_print_timings: prompt eval time = 133622.76 ms /  1160 tokens (  115.19 ms per token,     8.68 tokens per second)
# llama_print_timings:        eval time = 28941.19 ms /   177 runs   (  163.51 ms per token,     6.12 tokens per second)
# llama_print_timings:       total time = 163793.42 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   384.13 ms /   216 runs   (    1.78 ms per token,   562.31 tokens per second)
# llama_print_timings: prompt eval time = 127914.38 ms /  1084 tokens (  118.00 ms per token,     8.47 tokens per second)
# llama_print_timings:        eval time = 35419.61 ms /   215 runs   (  164.74 ms per token,     6.07 tokens per second)
# llama_print_timings:       total time = 164789.75 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   395.16 ms /   219 runs   (    1.80 ms per token,   554.20 tokens per second)
# llama_print_timings: prompt eval time = 123545.11 ms /  1052 tokens (  117.44 ms per token,     8.52 tokens per second)
# llama_print_timings:        eval time = 35815.55 ms /   218 runs   (  164.29 ms per token,     6.09 tokens per second)
# llama_print_timings:       total time = 160838.79 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   496.62 ms /   276 runs   (    1.80 ms per token,   555.75 tokens per second)
# llama_print_timings: prompt eval time = 117271.99 ms /  1000 tokens (  117.27 ms per token,     8.53 tokens per second)
# llama_print_timings:        eval time = 46076.92 ms /   276 runs   (  166.95 ms per token,     5.99 tokens per second)
# llama_print_timings:       total time = 165118.14 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   413.03 ms /   226 runs   (    1.83 ms per token,   547.17 tokens per second)
# llama_print_timings: prompt eval time = 119047.52 ms /   990 tokens (  120.25 ms per token,     8.32 tokens per second)
# llama_print_timings:        eval time = 38026.55 ms /   225 runs   (  169.01 ms per token,     5.92 tokens per second)
# llama_print_timings:       total time = 158591.26 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   638.11 ms /   338 runs   (    1.89 ms per token,   529.69 tokens per second)
# llama_print_timings: prompt eval time = 125537.26 ms /  1032 tokens (  121.64 ms per token,     8.22 tokens per second)
# llama_print_timings:        eval time = 59630.54 ms /   337 runs   (  176.95 ms per token,     5.65 tokens per second)
# llama_print_timings:       total time = 187377.88 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   409.58 ms /   215 runs   (    1.91 ms per token,   524.93 tokens per second)
# llama_print_timings: prompt eval time = 132617.43 ms /  1052 tokens (  126.06 ms per token,     7.93 tokens per second)
# llama_print_timings:        eval time = 37865.41 ms /   214 runs   (  176.94 ms per token,     5.65 tokens per second)
# llama_print_timings:       total time = 172020.02 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   474.80 ms /   258 runs   (    1.84 ms per token,   543.39 tokens per second)
# llama_print_timings: prompt eval time = 123397.08 ms /  1011 tokens (  122.05 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time = 44150.32 ms /   257 runs   (  171.79 ms per token,     5.82 tokens per second)
# llama_print_timings:       total time = 169269.22 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   456.52 ms /   236 runs   (    1.93 ms per token,   516.95 tokens per second)
# llama_print_timings: prompt eval time = 124612.75 ms /   999 tokens (  124.74 ms per token,     8.02 tokens per second)
# llama_print_timings:        eval time = 41339.08 ms /   235 runs   (  175.91 ms per token,     5.68 tokens per second)
# llama_print_timings:       total time = 167614.21 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   401.94 ms /   212 runs   (    1.90 ms per token,   527.45 tokens per second)
# llama_print_timings: prompt eval time = 129118.28 ms /  1035 tokens (  124.75 ms per token,     8.02 tokens per second)
# llama_print_timings:        eval time = 36884.53 ms /   211 runs   (  174.81 ms per token,     5.72 tokens per second)
# llama_print_timings:       total time = 167510.75 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   373.76 ms /   199 runs   (    1.88 ms per token,   532.43 tokens per second)
# llama_print_timings: prompt eval time = 118858.16 ms /   966 tokens (  123.04 ms per token,     8.13 tokens per second)
# llama_print_timings:        eval time = 34066.42 ms /   198 runs   (  172.05 ms per token,     5.81 tokens per second)
# llama_print_timings:       total time = 154331.37 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   389.43 ms /   209 runs   (    1.86 ms per token,   536.68 tokens per second)
# llama_print_timings: prompt eval time = 125762.21 ms /  1027 tokens (  122.46 ms per token,     8.17 tokens per second)
# llama_print_timings:        eval time = 35947.44 ms /   208 runs   (  172.82 ms per token,     5.79 tokens per second)
# llama_print_timings:       total time = 163178.82 ms
# Llama.generate: prefix-match hit
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   408.63 ms /   218 runs   (    1.87 ms per token,   533.48 tokens per second)
# llama_print_timings: prompt eval time = 113658.69 ms /   931 tokens (  122.08 ms per token,     8.19 tokens per second)
# llama_print_timings:        eval time = 38435.19 ms /   217 runs   (  177.12 ms per token,     5.65 tokens per second)
# llama_print_timings:       total time = 153596.54 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   214.02 ms /   213 runs   (    1.00 ms per token,   995.25 tokens per second)
# llama_print_timings: prompt eval time = 227211.34 ms /   973 tokens (  233.52 ms per token,     4.28 tokens per second)
# llama_print_timings:        eval time = 21951.10 ms /   212 runs   (  103.54 ms per token,     9.66 tokens per second)
# llama_print_timings:       total time = 250016.31 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   369.59 ms /   285 runs   (    1.30 ms per token,   771.12 tokens per second)
# llama_print_timings: prompt eval time = 91637.67 ms /  1028 tokens (   89.14 ms per token,    11.22 tokens per second)
# llama_print_timings:        eval time = 35865.25 ms /   284 runs   (  126.29 ms per token,     7.92 tokens per second)
# llama_print_timings:       total time = 128859.71 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   447.12 ms /   260 runs   (    1.72 ms per token,   581.49 tokens per second)
# llama_print_timings: prompt eval time = 106298.60 ms /  1000 tokens (  106.30 ms per token,     9.41 tokens per second)
# llama_print_timings:        eval time = 41497.74 ms /   260 runs   (  159.61 ms per token,     6.27 tokens per second)
# llama_print_timings:       total time = 149396.21 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   433.59 ms /   243 runs   (    1.78 ms per token,   560.43 tokens per second)
# llama_print_timings: prompt eval time = 127559.02 ms /  1088 tokens (  117.24 ms per token,     8.53 tokens per second)
# llama_print_timings:        eval time = 40879.56 ms /   242 runs   (  168.92 ms per token,     5.92 tokens per second)
# llama_print_timings:       total time = 170053.94 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   455.28 ms /   243 runs   (    1.87 ms per token,   533.74 tokens per second)
# llama_print_timings: prompt eval time = 121855.72 ms /   983 tokens (  123.96 ms per token,     8.07 tokens per second)
# llama_print_timings:        eval time = 41950.13 ms /   242 runs   (  173.35 ms per token,     5.77 tokens per second)
# llama_print_timings:       total time = 165466.07 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   468.79 ms /   256 runs   (    1.83 ms per token,   546.09 tokens per second)
# llama_print_timings: prompt eval time = 129569.30 ms /  1048 tokens (  123.63 ms per token,     8.09 tokens per second)
# llama_print_timings:        eval time = 43648.63 ms /   256 runs   (  170.50 ms per token,     5.87 tokens per second)
# llama_print_timings:       total time = 174952.17 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   498.30 ms /   268 runs   (    1.86 ms per token,   537.83 tokens per second)
# llama_print_timings: prompt eval time = 127768.32 ms /  1062 tokens (  120.31 ms per token,     8.31 tokens per second)
# llama_print_timings:        eval time = 46716.29 ms /   267 runs   (  174.97 ms per token,     5.72 tokens per second)
# llama_print_timings:       total time = 176300.65 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   321.90 ms /   179 runs   (    1.80 ms per token,   556.07 tokens per second)
# llama_print_timings: prompt eval time = 130930.59 ms /  1080 tokens (  121.23 ms per token,     8.25 tokens per second)
# llama_print_timings:        eval time = 29960.79 ms /   178 runs   (  168.32 ms per token,     5.94 tokens per second)
# llama_print_timings:       total time = 162178.11 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   435.09 ms /   248 runs   (    1.75 ms per token,   570.00 tokens per second)
# llama_print_timings: prompt eval time = 121131.87 ms /  1008 tokens (  120.17 ms per token,     8.32 tokens per second)
# llama_print_timings:        eval time = 40476.49 ms /   247 runs   (  163.87 ms per token,     6.10 tokens per second)
# llama_print_timings:       total time = 163215.99 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   339.11 ms /   196 runs   (    1.73 ms per token,   577.98 tokens per second)
# llama_print_timings: prompt eval time = 117802.37 ms /  1018 tokens (  115.72 ms per token,     8.64 tokens per second)
# llama_print_timings:        eval time = 31408.12 ms /   195 runs   (  161.07 ms per token,     6.21 tokens per second)
# llama_print_timings:       total time = 150514.17 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   172.52 ms /   206 runs   (    0.84 ms per token,  1194.04 tokens per second)
# llama_print_timings: prompt eval time = 478140.81 ms /  1026 tokens (  466.02 ms per token,     2.15 tokens per second)
# llama_print_timings:        eval time = 20071.70 ms /   205 runs   (   97.91 ms per token,    10.21 tokens per second)
# llama_print_timings:       total time = 498977.00 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   301.11 ms /   260 runs   (    1.16 ms per token,   863.48 tokens per second)
# llama_print_timings: prompt eval time = 82657.74 ms /  1038 tokens (   79.63 ms per token,    12.56 tokens per second)
# llama_print_timings:        eval time = 30921.49 ms /   259 runs   (  119.39 ms per token,     8.38 tokens per second)
# llama_print_timings:       total time = 114724.34 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   394.59 ms /   319 runs   (    1.24 ms per token,   808.44 tokens per second)
# llama_print_timings: prompt eval time = 99441.31 ms /  1095 tokens (   90.81 ms per token,    11.01 tokens per second)
# llama_print_timings:        eval time = 39438.54 ms /   318 runs   (  124.02 ms per token,     8.06 tokens per second)
# llama_print_timings:       total time = 140355.62 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   272.29 ms /   219 runs   (    1.24 ms per token,   804.29 tokens per second)
# llama_print_timings: prompt eval time = 92952.51 ms /   992 tokens (   93.70 ms per token,    10.67 tokens per second)
# llama_print_timings:        eval time = 26646.77 ms /   218 runs   (  122.23 ms per token,     8.18 tokens per second)
# llama_print_timings:       total time = 120672.43 ms
# Llama.generate: prefix-match hit
# Generating Summaries:  57%|█████████████████████████████████████████▏                              | 4/7 [3:24:13<2:55:12, 3504.01s/it]
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   370.74 ms /   284 runs   (    1.31 ms per token,   766.03 tokens per second)
# llama_print_timings: prompt eval time = 84142.05 ms /   893 tokens (   94.22 ms per token,    10.61 tokens per second)
# llama_print_timings:        eval time = 35422.40 ms /   283 runs   (  125.17 ms per token,     7.99 tokens per second)
# llama_print_timings:       total time = 120895.78 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   231.55 ms /   210 runs   (    1.10 ms per token,   906.92 tokens per second)
# llama_print_timings: prompt eval time = 104977.37 ms /  1093 tokens (   96.05 ms per token,    10.41 tokens per second)
# llama_print_timings:        eval time = 194305.35 ms /   209 runs   (  929.69 ms per token,     1.08 tokens per second)
# llama_print_timings:       total time = 300260.04 ms
# Llama.generate: prefix-match hit
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   182.10 ms /   158 runs   (    1.15 ms per token,   867.67 tokens per second)
# llama_print_timings: prompt eval time = 86651.82 ms /  1116 tokens (   77.65 ms per token,    12.88 tokens per second)
# llama_print_timings:        eval time = 18215.21 ms /   157 runs   (  116.02 ms per token,     8.62 tokens per second)
# llama_print_timings:       total time = 105642.98 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   311.96 ms /   243 runs   (    1.28 ms per token,   778.95 tokens per second)
# llama_print_timings: prompt eval time = 97891.78 ms /  1064 tokens (   92.00 ms per token,    10.87 tokens per second)
# llama_print_timings:        eval time = 30348.24 ms /   242 runs   (  125.41 ms per token,     7.97 tokens per second)
# llama_print_timings:       total time = 129425.95 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   365.03 ms /   237 runs   (    1.54 ms per token,   649.26 tokens per second)
# llama_print_timings: prompt eval time = 104222.01 ms /  1059 tokens (   98.42 ms per token,    10.16 tokens per second)
# llama_print_timings:        eval time = 34714.04 ms /   236 runs   (  147.09 ms per token,     6.80 tokens per second)
# llama_print_timings:       total time = 140290.62 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   455.39 ms /   276 runs   (    1.65 ms per token,   606.08 tokens per second)
# llama_print_timings: prompt eval time = 108839.02 ms /  1020 tokens (  106.70 ms per token,     9.37 tokens per second)
# llama_print_timings:        eval time = 42555.12 ms /   275 runs   (  154.75 ms per token,     6.46 tokens per second)
# llama_print_timings:       total time = 153026.83 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   283.44 ms /   209 runs   (    1.36 ms per token,   737.36 tokens per second)
# llama_print_timings: prompt eval time = 108989.61 ms /   994 tokens (  109.65 ms per token,     9.12 tokens per second)
# llama_print_timings:        eval time = 26855.95 ms /   208 runs   (  129.12 ms per token,     7.75 tokens per second)
# llama_print_timings:       total time = 136971.95 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   288.33 ms /   245 runs   (    1.18 ms per token,   849.71 tokens per second)
# llama_print_timings: prompt eval time = 194038.27 ms /  1068 tokens (  181.68 ms per token,     5.50 tokens per second)
# llama_print_timings:        eval time = 28432.22 ms /   244 runs   (  116.53 ms per token,     8.58 tokens per second)
# llama_print_timings:       total time = 223555.94 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   255.33 ms /   187 runs   (    1.37 ms per token,   732.38 tokens per second)
# llama_print_timings: prompt eval time = 108844.86 ms /  1162 tokens (   93.67 ms per token,    10.68 tokens per second)
# llama_print_timings:        eval time = 24726.25 ms /   186 runs   (  132.94 ms per token,     7.52 tokens per second)
# llama_print_timings:       total time = 134620.67 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   239.40 ms /   155 runs   (    1.54 ms per token,   647.46 tokens per second)
# llama_print_timings: prompt eval time = 115985.29 ms /  1132 tokens (  102.46 ms per token,     9.76 tokens per second)
# llama_print_timings:        eval time = 22819.60 ms /   154 runs   (  148.18 ms per token,     6.75 tokens per second)
# llama_print_timings:       total time = 139823.07 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   327.73 ms /   201 runs   (    1.63 ms per token,   613.32 tokens per second)
# llama_print_timings: prompt eval time = 110479.17 ms /  1032 tokens (  107.05 ms per token,     9.34 tokens per second)
# llama_print_timings:        eval time = 30703.83 ms /   201 runs   (  152.76 ms per token,     6.55 tokens per second)
# llama_print_timings:       total time = 142446.80 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   419.93 ms /   241 runs   (    1.74 ms per token,   573.91 tokens per second)
# llama_print_timings: prompt eval time = 108048.33 ms /   956 tokens (  113.02 ms per token,     8.85 tokens per second)
# llama_print_timings:        eval time = 38639.70 ms /   240 runs   (  161.00 ms per token,     6.21 tokens per second)
# llama_print_timings:       total time = 148211.64 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   495.98 ms /   279 runs   (    1.78 ms per token,   562.53 tokens per second)
# llama_print_timings: prompt eval time = 125414.54 ms /  1076 tokens (  116.56 ms per token,     8.58 tokens per second)
# llama_print_timings:        eval time = 46047.08 ms /   278 runs   (  165.64 ms per token,     6.04 tokens per second)
# llama_print_timings:       total time = 173260.11 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   414.71 ms /   231 runs   (    1.80 ms per token,   557.01 tokens per second)
# llama_print_timings: prompt eval time = 127674.46 ms /  1071 tokens (  119.21 ms per token,     8.39 tokens per second)
# llama_print_timings:        eval time = 38362.48 ms /   230 runs   (  166.79 ms per token,     6.00 tokens per second)
# llama_print_timings:       total time = 167594.51 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   333.87 ms /   273 runs   (    1.22 ms per token,   817.68 tokens per second)
# llama_print_timings: prompt eval time = 131973.25 ms /  1120 tokens (  117.83 ms per token,     8.49 tokens per second)
# llama_print_timings:        eval time = 36175.77 ms /   273 runs   (  132.51 ms per token,     7.55 tokens per second)
# llama_print_timings:       total time = 169504.05 ms
# Llama.generate: prefix-match hit
# Generating Summaries:  71%|███████████████████████████████████████████████████▍                    | 5/7 [4:02:17<1:42:07, 3063.87s/it]
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   197.02 ms /   138 runs   (    1.43 ms per token,   700.43 tokens per second)
# llama_print_timings: prompt eval time =  2954.52 ms /    31 tokens (   95.31 ms per token,    10.49 tokens per second)
# llama_print_timings:        eval time = 15216.72 ms /   137 runs   (  111.07 ms per token,     9.00 tokens per second)
# llama_print_timings:       total time = 18753.10 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   377.40 ms /   212 runs   (    1.78 ms per token,   561.74 tokens per second)
# llama_print_timings: prompt eval time = 112021.76 ms /  1039 tokens (  107.82 ms per token,     9.27 tokens per second)
# llama_print_timings:        eval time = 34885.25 ms /   211 runs   (  165.33 ms per token,     6.05 tokens per second)
# llama_print_timings:       total time = 148309.98 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   550.23 ms /   300 runs   (    1.83 ms per token,   545.23 tokens per second)
# llama_print_timings: prompt eval time = 125338.35 ms /  1021 tokens (  122.76 ms per token,     8.15 tokens per second)
# llama_print_timings:        eval time = 51634.23 ms /   299 runs   (  172.69 ms per token,     5.79 tokens per second)
# llama_print_timings:       total time = 178929.08 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   352.72 ms /   219 runs   (    1.61 ms per token,   620.88 tokens per second)
# llama_print_timings: prompt eval time = 124230.74 ms /  1055 tokens (  117.75 ms per token,     8.49 tokens per second)
# llama_print_timings:        eval time = 37440.48 ms /   218 runs   (  171.75 ms per token,     5.82 tokens per second)
# llama_print_timings:       total time = 163034.08 ms
# Llama.generate: prefix-match hit
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   338.09 ms /   195 runs   (    1.73 ms per token,   576.77 tokens per second)
# llama_print_timings: prompt eval time = 103630.27 ms /  1002 tokens (  103.42 ms per token,     9.67 tokens per second)
# llama_print_timings:        eval time = 31171.05 ms /   194 runs   (  160.68 ms per token,     6.22 tokens per second)
# llama_print_timings:       total time = 136071.86 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   238.46 ms /   259 runs   (    0.92 ms per token,  1086.12 tokens per second)
# llama_print_timings: prompt eval time = 553684.64 ms /   920 tokens (  601.83 ms per token,     1.66 tokens per second)
# llama_print_timings:        eval time = 25023.11 ms /   258 runs   (   96.99 ms per token,    10.31 tokens per second)
# llama_print_timings:       total time = 579649.15 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   484.84 ms /   407 runs   (    1.19 ms per token,   839.45 tokens per second)
# llama_print_timings: prompt eval time = 93239.92 ms /  1098 tokens (   84.92 ms per token,    11.78 tokens per second)
# llama_print_timings:        eval time = 49094.82 ms /   406 runs   (  120.92 ms per token,     8.27 tokens per second)
# llama_print_timings:       total time = 144078.19 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   246.76 ms /   200 runs   (    1.23 ms per token,   810.52 tokens per second)
# llama_print_timings: prompt eval time = 104093.54 ms /  1128 tokens (   92.28 ms per token,    10.84 tokens per second)
# llama_print_timings:        eval time = 24265.39 ms /   199 runs   (  121.94 ms per token,     8.20 tokens per second)
# llama_print_timings:       total time = 129382.54 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   205.11 ms /   161 runs   (    1.27 ms per token,   784.96 tokens per second)
# llama_print_timings: prompt eval time = 100439.16 ms /  1051 tokens (   95.57 ms per token,    10.46 tokens per second)
# llama_print_timings:        eval time = 19911.12 ms /   160 runs   (  124.44 ms per token,     8.04 tokens per second)
# llama_print_timings:       total time = 121234.58 ms
# Llama.generate: prefix-match hit
# Generating Summaries:  86%|███████████████████████████████████████████████████████████████▍          | 6/7 [4:29:38<43:00, 2580.09s/it]
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   252.16 ms /   187 runs   (    1.35 ms per token,   741.58 tokens per second)
# llama_print_timings: prompt eval time = 18936.51 ms /   202 tokens (   93.75 ms per token,    10.67 tokens per second)
# llama_print_timings:        eval time = 20531.87 ms /   186 runs   (  110.39 ms per token,     9.06 tokens per second)
# llama_print_timings:       total time = 40266.38 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   227.91 ms /   168 runs   (    1.36 ms per token,   737.14 tokens per second)
# llama_print_timings: prompt eval time = 99092.72 ms /  1030 tokens (   96.21 ms per token,    10.39 tokens per second)
# llama_print_timings:        eval time = 21770.38 ms /   167 runs   (  130.36 ms per token,     7.67 tokens per second)
# llama_print_timings:       total time = 121809.03 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   422.66 ms /   257 runs   (    1.64 ms per token,   608.05 tokens per second)
# llama_print_timings: prompt eval time = 117770.87 ms /  1126 tokens (  104.59 ms per token,     9.56 tokens per second)
# llama_print_timings:        eval time = 41329.84 ms /   256 runs   (  161.44 ms per token,     6.19 tokens per second)
# llama_print_timings:       total time = 160661.86 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   383.94 ms /   207 runs   (    1.85 ms per token,   539.15 tokens per second)
# llama_print_timings: prompt eval time = 129928.47 ms /  1052 tokens (  123.51 ms per token,     8.10 tokens per second)
# llama_print_timings:        eval time = 35957.51 ms /   206 runs   (  174.55 ms per token,     5.73 tokens per second)
# llama_print_timings:       total time = 167339.77 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   569.18 ms /   299 runs   (    1.90 ms per token,   525.32 tokens per second)
# llama_print_timings: prompt eval time = 126274.80 ms /   994 tokens (  127.04 ms per token,     7.87 tokens per second)
# llama_print_timings:        eval time = 52415.47 ms /   298 runs   (  175.89 ms per token,     5.69 tokens per second)
# llama_print_timings:       total time = 180687.58 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =   389.55 ms /   277 runs   (    1.41 ms per token,   711.09 tokens per second)
# llama_print_timings: prompt eval time = 97826.62 ms /   973 tokens (  100.54 ms per token,     9.95 tokens per second)
# llama_print_timings:        eval time = 37140.22 ms /   276 runs   (  134.57 ms per token,     7.43 tokens per second)
# llama_print_timings:       total time = 136356.12 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6426.74 ms
# llama_print_timings:      sample time =  1121.18 ms /   596 runs   (    1.88 ms per token,   531.58 tokens per second)
# llama_print_timings: prompt eval time = 93969.06 ms /   792 tokens (  118.65 ms per token,     8.43 tokens per second)
# Generating Summaries: 100%|██████████████████████████████████████████████████████████████████████████| 7/7 [4:45:47<00:00, 2053.38s/it]llama_print_timings:        eval time = 104457.97 ms /   595 runs   (  175.56 ms per token,     5.70 tokens per second)
# llama_print_timings:       total time = 202088.17 ms
# Generating Summaries: 100%|██████████████████████████████████████████████████████████████████████████| 7/7 [4:45:47<00:00, 2449.57s/it]

# %%
df[["wonder_city", "summary"]]
# Out:
#     wonder_city                                            summary
# 0        Beirut  1. Beirut is the capital and largest city of L...
# 1          Doha  1. Doha is the capital city and financial hub ...
# 2        Durban  1. Durban is located in KwaZulu-Natal, South A...
# 3        Havana  1) Havana is the capital and largest city of C...
# 4  Kuala Lumpur  1. Kuala Lumpur is the capital city of Malaysi...
# 5        La Paz  1. La Paz is a capital city in Bolivia, locate...
# 6         Vigan  1. Vigan is a 4th class component city and cap...

# %%
df['summary_token_count'] = df["summary"].apply(count_tokens)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (6909 > 4096). Running this sequence through the model will result in indexing errors

# %%
df.head()
# Out:
#     wonder_city                                        information  \
# 0        Beirut  Beirut is the capital and largest city  of  Le...
# 1          Doha  Doha (Arabic: الدوحة, romanized: ad-Dawḥa [adˈ...
# 2        Durban  Durban ( DUR-bən) (Zulu: eThekwini, from ithek...
# 3        Havana  Havana (; Spanish: La Habana [la aˈβana] ; Luc...
# 4  Kuala Lumpur  Kuala Lumpur (Malaysian pronunciation: [ˈkualə...
#
#    num_tokens                                cleaned_information  token_count  \
# 0       12695  beirut is the capital and largest city of leba...        12121
# 1        9016  doha (arabic romanized addawa [addua] or adda)...         8252
# 2        7992  durban ( durbn) (zulu ethekwini from itheku me...         7395
# 3       30000  havana ( spanish la habana [la aana] lucumi il...        28979
# 4       12584  kuala lumpur (malaysian pronunciation [kual a ...        12397
#
#                                              summary  summary_token_count
# 0  1. Beirut is the capital and largest city of L...                 2806
# 1  1. Doha is the capital city and financial hub ...                 1645
# 2  1. Durban is located in KwaZulu-Natal, South A...                 2151
# 3  1) Havana is the capital and largest city of C...                 6909
# 4  1. Kuala Lumpur is the capital city of Malaysi...                 2721

# %%
rouge = Rouge()
def calculate_rouge_scores(row):
    cleaned_information = row['cleaned_information']
    summary = row['summary']
    scores = rouge.get_scores(summary, cleaned_information)
    return scores

# %%
df['rouge_scores'] = df.apply(calculate_rouge_scores, axis=1)

# %%
df[['wonder_city', 'cleaned_information', 'summary', 'rouge_scores']]
# Out:
#     wonder_city                                cleaned_information  \
# 0        Beirut  beirut is the capital and largest city of leba...
# 1          Doha  doha (arabic romanized addawa [addua] or adda)...
# 2        Durban  durban ( durbn) (zulu ethekwini from itheku me...
# 3        Havana  havana ( spanish la habana [la aana] lucumi il...
# 4  Kuala Lumpur  kuala lumpur (malaysian pronunciation [kual a ...
# 5        La Paz  la paz officially known as nuestra seora de la...
# 6         Vigan  vigan officially the city of vigan (ilocano si...
#
#                                              summary  \
# 0  1. Beirut is the capital and largest city of L...
# 1  1. Doha is the capital city and financial hub ...
# 2  1. Durban is located in KwaZulu-Natal, South A...
# 3  1) Havana is the capital and largest city of C...
# 4  1. Kuala Lumpur is the capital city of Malaysi...
# 5  1. La Paz is a capital city in Bolivia, locate...
# 6  1. Vigan is a 4th class component city and cap...
#
#                                         rouge_scores
# 0  [{'rouge-1': {'r': 0.18871940404398724, 'p': 0...
# 1  [{'rouge-1': {'r': 0.17232640648758235, 'p': 0...
# 2  [{'rouge-1': {'r': 0.19918074756784435, 'p': 0...
# 3  [{'rouge-1': {'r': 0.22426397945070145, 'p': 0...
# 4  [{'rouge-1': {'r': 0.19829683698296838, 'p': 0...
# 5  [{'rouge-1': {'r': 0.19287671232876713, 'p': 0...
# 6  [{'rouge-1': {'r': 0.21536252692031588, 'p': 0...

# %%
df.head(10)
# Out:
#     wonder_city                                        information  \
# 0        Beirut  Beirut is the capital and largest city  of  Le...
# 1          Doha  Doha (Arabic: الدوحة, romanized: ad-Dawḥa [adˈ...
# 2        Durban  Durban ( DUR-bən) (Zulu: eThekwini, from ithek...
# 3        Havana  Havana (; Spanish: La Habana [la aˈβana] ; Luc...
# 4  Kuala Lumpur  Kuala Lumpur (Malaysian pronunciation: [ˈkualə...
# 5        La Paz  La Paz, officially known as Nuestra Señora de ...
# 6         Vigan  Vigan, officially the City of Vigan (Ilocano: ...
#
#    num_tokens                                cleaned_information  token_count  \
# 0       12695  beirut is the capital and largest city of leba...        12121
# 1        9016  doha (arabic romanized addawa [addua] or adda)...         8252
# 2        7992  durban ( durbn) (zulu ethekwini from itheku me...         7395
# 3       30000  havana ( spanish la habana [la aana] lucumi il...        28979
# 4       12584  kuala lumpur (malaysian pronunciation [kual a ...        12397
# 5        8177  la paz officially known as nuestra seora de la...         7427
# 6        5679  vigan officially the city of vigan (ilocano si...         5234
#
#                                              summary  summary_token_count  \
# 0  1. Beirut is the capital and largest city of L...                 2806
# 1  1. Doha is the capital city and financial hub ...                 1645
# 2  1. Durban is located in KwaZulu-Natal, South A...                 2151
# 3  1) Havana is the capital and largest city of C...                 6909
# 4  1. Kuala Lumpur is the capital city of Malaysi...                 2721
# 5  1. La Paz is a capital city in Bolivia, locate...                 1957
# 6  1. Vigan is a 4th class component city and cap...                 1576
#
#                                         rouge_scores
# 0  [{'rouge-1': {'r': 0.18871940404398724, 'p': 0...
# 1  [{'rouge-1': {'r': 0.17232640648758235, 'p': 0...
# 2  [{'rouge-1': {'r': 0.19918074756784435, 'p': 0...
# 3  [{'rouge-1': {'r': 0.22426397945070145, 'p': 0...
# 4  [{'rouge-1': {'r': 0.19829683698296838, 'p': 0...
# 5  [{'rouge-1': {'r': 0.19287671232876713, 'p': 0...
# 6  [{'rouge-1': {'r': 0.21536252692031588, 'p': 0...

# %%
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting termcolor
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Installing collected packages: termcolor
# Successfully installed termcolor-2.3.0

# %%
selected_columns = df[["wonder_city", "summary"]]

for index, row in selected_columns.iterrows():
    wonder_city = row["wonder_city"]
    summary = row["summary"]

    formatted_wonder_city = colored(wonder_city, "green", attrs=["bold", "underline"])
    
    formatted_summary = colored(f"Summary: {summary}", "black")
    
    print(formatted_wonder_city)
    
    print()
    
    print(formatted_summary)
    
    print("\n----------------------------------------------\n")
# Out:
# Beirut
#
# Summary: 1. Beirut is the capital and largest city of Lebanon with a population of 2.5 million people as of 2014.
#     2. The city has been inhabited for over 5,000 years and was one of the oldest cities in the world.
#     3. The first historical mention of Beirut is found in the Amarna letters from the New Kingdom of Egypt which date back to the 14th century BC.
#     4. Beirut has been severely damaged by the Lebanese Civil War, the 2006 Lebanon War, and the 2020 massive explosion in the port of Beirut.
#     5. The city's architectural and demographic structure has undergone major changes in recent decades.
# 1. The text describes the discovery of several archaeological sites in Beirut, Lebanon, including Beirut V (Nahr Beirut), Beirut VI (Patriarchate), Beirut VII (Rivoli and Byblos Cinemas), and Beirut 194.
#     2. The sites were discovered by various archaeologists, including Henri Fleisch, Dillenseger, Lorraine Copeland, Peter Wescombe, Marina Hayek, and an international committee of archaeologists appointed by the Lebanese Minister of Culture.
#     3. The discoveries included Middle Paleolithic flint tools, Hellenistic-era remains, and Roman pottery and mosaics.
#     4. Controversy arose in 2012 when authorization was given to a private company to destroy the ruins at Beirut 194 during a construction project.
#     5. The text highlights the importance of preserving Lebanon's cultural heritage and the need for thorough archaeological investigations to understand the country's history and identity.
# 1. Berytus (Beirut) was an important city in the Roman Empire, known for its architecture, including several bath complexes, colonnaded streets, a circus, theatre, residential areas, and a law school that became one of the three official law schools of the empire.
# 2. In 635, Beirut was conquered by Muslims and became part of the Principality of Sin el Fil, which later developed into the Principality of Mount Lebanon.
# 3. Beirut played an important role as a trading center in the eastern Mediterranean during the Middle Ages, being as important as Acre (in modern-day Israel).
# 4. In 1110, the town and lordship of Beirut became part of the Kingdom of Jerusalem, but it was taken by Saladin in 1187 and recaptured in 1197 by Henry I of Brabant as part of the German Crusade of 1197.
# 5. In 1291, Beirut was captured and the crusaders were expelled by the Mamluk army of Sultan Alashraf Khalil, marking the end of Ottoman rule in the region.
# 1) Beirut was a small town with a population of about 10,000 before Ibrahim Pasha of Egypt captured Acre in 1832, leading to Beirut's revival.
# 2) European interests in Lebanese silk and other export products transformed Beirut into a major port and commercial center by the second half of the nineteenth century.
# 3) The establishment of the Beirut Municipal Council in 1870 was instrumental in governing the city, with elections held by an assembly of city notables.
# 2. The city has numerous old mosques and churches, as well as ruins from the Roman era.
# 3. The Corniche, a 4.8 km pedestrian promenade, surrounds the city's seafront and is popular for both daytime and evening activities.
# 4. Badaro is one of Beirut's most appealing neighborhoods, with small groceries, restaurants, and cafes. It has become a hip destination for young and restless Beirutis and expatriates.
# 5. Hamra Street is a long cobblestone street connecting the central district with the coastal Raouche area, and is home to many shopping stores, restaurants, and nightlife spots.
# 1) Lebanon is strongly trying to attract more Southern Europeans, Asians, and North Americans to its medical tourism industry, which has been growing at a rate of up to 30% per year since 2009.
#     2) The government is working closely with the medical sector and top-class hotels to create an organized and quality medical destination.
#     3) Major hotel and spa chains are collaborating with local clinics, travel agencies, and the tourism ministry to create comprehensive healthcare and recuperation packages for foreign visitors.
#     4) Beirut is home to numerous international organizations, including the United Nations Economic and Social Commission for Western Asia (ESCWA), the Arab Air Carriers Organization (AACO), and the World Youth Alliance.
#     5) Education in Beirut is provided by universities, colleges, and technical and vocational institutes, with the Directorate General of Higher Education managing these institutions nationwide. Some of the prominent English-language and French-language universities include the American University of Beirut (AUB), the Lebanese University, and the Universit Saint-Joseph (USJ).
# 1. Beirut has an extensive public transportation system, including buses for northern destinations and Syria, and a bike-sharing service.
#     2. The city's culture has been influenced by various civilizations, such as the Greeks, Romans, Arabs, Ottomans, and French, resulting in a unique blend of traditions. Beirut was home to one of the world's earliest law schools and hosted international events like the Francophonie and Arab League summits.
#     3. Beirut has a vibrant nightlife scene with many bars, clubs, and alleyways popular among partygoers. The city is known as the "party capital of the Arab world."
#     4. Beirut has several museums, including the National Museum of Beirut, which exhibits artifacts from prehistoric times to the medieval period; the Archaeological Museum of the American University of Beirut; and the Sursock Museum, which houses influential artworks.
#     5. The city offers a variety of tourist attractions, such as Mim Museum, a private mineral museum showcasing over 2000 minerals from around the world, and Fishnstone, an exhibition featuring marine fossils quarried in the Lebanese mountains.
# 1. Beirut is considered one of the most expensive cities in the Middle East and upper middle income countries, according to a 2010 study by Mercer.
#     2. The city has an active and diverse nightlife, with bars, dance clubs, and nightclubs staying open late into the night.
#     3. In 2011, Mastercard Index revealed that Beirut had the second-highest visitor spending levels in the Middle East and Africa, totaling $6.5 billion.
#     4. Beirut was chosen as the best city in the Middle East by Condé Nast Traveler in 2012, and ranked as one of the top 20 best cities in the world in 2013.
#     5. In 2016, Yahoo listed Beirut as the best international city for food, travel, and leisure, and Travel + Leisure ranked it among the top 15 of the world's best cities.
# 1) Beirut is a city with various amenities such as a screening and performance room, mediatheque, book store, cafe, and terrace. It also hosts cultural events and educational programs.
#     2) International fashion designers have showcased their work in big fashion shows in Beirut, and many major fashion labels have shops in the city's shopping districts. Local fashion designers like Elie Saab, Yara Farhat, Reem Acra, Zuhair Murad, Georges Chakra, Jean Faris, Nicolas Jebran, Rabih Kayrouz, and Abed Mahfouz have achieved international fame.
#     3) Beirut has a vibrant street art scene, with notable artists like Yazan Halwani who produces large murals on the walls of Beirut in areas such as Gemmayzeh, Hamra, Verdun, and Achrafieh.
# 1. Doha, Qatar has gained significant media attention due to the hosting of global events and the launch of architectural megaprojects.
#     2. The government launched a restoration program to preserve Souq Waqif's architectural and historical identity.
#     3. Katara Cultural Village was opened in the city and hosts the Doha Tribeca Film Festival.
#     4. The World Trade Organization Ministerial Conference of 2013 led to the trade facilitation agreement, which aims to make it easier and cheaper to import and export by improving customs procedures and making rules more transparent.
#     5. Modernizing the city while preserving traditions is part of Qatar's long-term plan, Qatar National Vision 2030.
# 1. Doha has a high population density, ranging from 20,000 to 25,500 people per square kilometer.
#
#
#
#
#
# 1) Qatar's real estate prices increased substantially after a peak in 2008, with prices increasing by 5-10% in the first quarter of 2014 from the end of 2013.
# 2) Doha was named the 10th most expensive city to live in globally in a 2015 study.
# 3) Expatriate workers remitted $60 billion between 2006 and 2012, with 54% of the remittances routed to Asian countries and 28% going to Arab nations.
# 4) Remittances in 2014 totaled $11.2 billion, amounting to 5.3% of Qatar's GDP.
# 5) Qatar is investing heavily in new infrastructure projects, including a $65 billion spending plan for the next few years to prepare for the 2022 World Cup and progress towards its objectives set out in the Qatar National Vision 2030.
# 1) Qatar has invested heavily in its transportation network, including new highways, airport expansions, and a metro system.
#     2) The latest project is the Sharq Crossing, which will involve three extensions connected by subsea tunnels.
#     3) Doha Metro is currently 3/4ths complete, with four lines (red, gold, blue, and green). The red line will extend from Al Khor to Al Wakrah and Hamad International Airport via the north and south routes.
#     4) Qatar's airport, Hamad International Airport, is the country's principal international gateway and has been named the world's best airport for two years in a row.
#     5) Education City is Qatar's educational center, with numerous schools and universities, including Qatar University, which was opened in 1973.
# 1. Doha, Qatar has hosted several international sports events including the 1988 and 2011 AFC Asian Cups, the 1995 FIFA World Youth Championship, and the 2022 FIFA World Cup.
#     2. Three of the nine newly announced stadiums for the 2022 FIFA World Cup will be constructed in Doha, including the Khalifa International Stadium, which is set to undergo an expansion.
#     3. Qatar has also hosted the 2019 and 2020 FIFA Club World Cups and the 2017 World Mindsports Championships.
#     4. Doha has a rich history of hosting international tennis tournaments, including the Qatar Ladies Open and the Sony Ericsson Championship.
#     5. The city is also expected to host the 2030 Asian Games and has submitted bids for the 2016 and 2020 Summer Olympics.
# 1. The Ministry of Culture organized cultural weeks in Doha to celebrate the city's selection.
#     2. The Museum of Islamic Art (MIA) is regarded as one of the best museums in the region, located in Doha since 2008.
#     3. The National Museum of Qatar opened on March 28, 2019, replacing the original national museum.
#     4. The Doha Film Institute (DFI) was established in 2010 to promote film initiatives and create a sustainable industry in Qatar.
#     5. Doha has hosted various international events, including the Doha Tribeca Film Festival (DTFF), which ran from 2009 to 2012 in partnership with the American-based Tribeca Film Festival.
#
# ----------------------------------------------
#
# Durban
#
# Summary: 1. Durban is located in KwaZulu-Natal, South Africa and is the third most populous city in the country after Johannesburg and Cape Town.
# 2. The city was formerly known as Port Natal due to its position as the chief seaport of South Africa and its location on the Natal Bay of the Indian Ocean.
# 3. Durban has a rich ethnic diversity with large Zulu, white, and Indian populations.
#      * Durban also hosts the Durban Youth Council, Emmanuel Cathedral, Riverside, Soofie Mosque, and Mausoleum, as well as the World Conference against Racism held in 2001.
#
# ----------------------------------------------
#
# Havana
#
# Summary: 1) Havana is the capital and largest city of Cuba, with a population of 2.3 million inhabitants and spanning an area of 728.26 km2 (281.18 sq mi).
#         * The city was founded by the Spanish in the 16th century and served as a springboard for their conquest of the Americas.
#        * Havana has been a center of commerce and trade, with over 100 diplomatic offices and headquarters of businesses located there.
#     2) The city is divided into three main areas: Old Havana, Vedado, and newer suburban districts.
#         * The Almendares River runs through the city from south to north, entering the Straits of Florida a few miles west of the bay.
#      3) Havana attracts over one million tourists annually and is known for its history, culture, architecture, and monuments.
#     4) The city experiences a tropical climate and is noted for its etymology, which is not clear where the name derived from but has been theorized to come from the chief of the native American tribe, Habaguanex.
#      5) Havana's coat of arms consists of three castles, representing the three castles that defended the city, and a shield supported by an oak branch and a laurel wreath, symbolizing the strength of the nation and the rights of man.
# 1) Havana originated as a trading port in 1519, named San Cristobal de la Habana due to its strategic natural bay.
# 2) The city suffered regular attacks by pirates and corsairs, leading to the construction of fortresses to counteract these threats.
# 3) In 1592, King Philip II of Spain granted Havana the title of City, and it was officially designated as "Key to the New World" and "Rampart of the West Indies" by the Spanish Crown.
# 4) The city expanded greatly in the 17th century, with new buildings constructed using abundant local materials and combining Iberian and Canarian architectural styles.
# 5) In 1649, a deadly epidemic affected a third of Havana's population, and in 1665, Queen Mariana of Austria ratified the heraldic shield of Cuba, which featured symbolic motifs from Havana's three castles and a golden key to represent the city's strategic importance.
# 1) The Treaty of Paris ended the Seven Years War, giving Britain Florida in exchange for Havana's return to Spain.
#     2) After regaining Havana, Spain transformed it into the most heavily fortified city in the Americas, constructing the Forth of San Carlos de la Cabaña.
#     3) Christopher Columbus' remains were transported to Havana from Santo Domingo in 1796 and later transferred to Seville Cathedral after Spain lost Cuba.
#     4) In the 19th century, Havana became a flourishing and fashionable city, with expensive new classical mansions being erected and a railroad constructed in 1837, making Cuba the fifth country to have a railroad and the first Spanish-speaking country.
#     5) Despite improvements in infrastructure, communication, and public health during President Tomás Estrada Palma's term (1902-1906), he allowed the Platt Amendment to be enacted, ensuring American political and economic dominance over Cuba.
# 1. In 1959, a revolution in Cuba led to significant changes in the country's economy and society, including the nationalization of land and industry, an increase in social services and public housing, and the creation of a communist government backed by the Soviet Union.
# 2. The revolution was marked by disparities between the rich and poor, with the bottom 20% of the population taking in only 2% of the national income while the top 5% took in 58%.
# 3. The Cuban government under Fidel Castro began a program of nationalization, centralization, and political consolidation after the revolution, which transformed Cuba's economy and civil society.
# 4. The revolution also led to an era of Cuban medical internationalism and intervention in foreign conflicts, as well as rebellions in the Escambray mountains that were defeated by the revolutionary government.
# 5. In response to the collapse of the Soviet Union in 1991, Cuba experienced an economic downturn, but the socialist government has since turned to tourism for revenue and foreign investment to develop a new hospitality industry.
# 1) The Governor of Havana is Reinaldo Garca Zapata, elected on January 18, 2020.
#     2) Havana functions as both a city and a province of Cuba, with little autonomy and dependence on the national government for budgetary and political direction.
#     2. The building was conceived and designed based on Corbusian ideas of a self-contained city within a city.
#     3. It contains 400 apartments, a school, supermarket, and restaurant on the top floor, making it the tallest high-strength concrete structure in the world at the time.
#     4. The building's walls are solid and have no openings except at the basement and lobby floors, and there is an additional concrete mass at the center of the Y (apartments F and G) to increase resistance to lateral forces.
#     5. The text also mentions the Edificio del Seguro Medico, a commercial building in El Vedado Havana built between 1955 and 1958 for the headquarters of the National Medical Insurance Company.
# 1) Carlos Alberto Odio Soto observed that the Medical Insurance Building designed by Antonio Quintana in 1955 was praised before its inauguration by Professor Pedro Martínez, who believed that Quintana had endowed Havana with modern architecture.
# 2) Quintana received recognition from mainstream Cuban publications and international publications such as the Museum of Modern Art's Latin American Architecture book.
# 3) In 1959, Quintana received two distinctions: the Gold Medal Award of the National College of Architects and the Condition of Best Commercial Work of this Period.
# 4) Today, the building houses the Cuban Ministry of Public Health and Prensa Latina Agency.
# 5) The only complete package of information about the building is a set of slides presented in the magazine Arquitectura n°269 of 1955 published by the College of Architects of Havana.
# 1. The population of Havana has grown slowly since the 1980s due to balanced development policies, low birth rate, and controlled domestic migration.
#     2. The city's age structure is similar to a developed country with a high proportion of elderly people.
#     3. Havana has a diverse ethnic breakdown, with the majority being white (58.4%), followed by mestizo or mulatto (26.4%), black (15.2%), and Asian (0.2%).
#     4. The Cuban government controls migration into Havana to address infrastructure challenges due to the city's overstretched resources.
#     5. Havana has a significant minority of Chinese, mostly of Cantonese ancestry, who were brought in the mid-19th century by Spanish settlers. The city also shelters other non-Cuban populations, including North African teen and preteen refugees.
# 1) Havana was once a rich city due to its sugar and slave trade, but after independence it became a resort town.
#     2) The traditional sugar industry is centered elsewhere on the island, but light manufacturing facilities, meatpacking plants, chemical and pharmaceutical operations are concentrated in Havana.
#     3) Havana remains Cuba's primary port facility, with 50% of Cuban imports and exports passing through it. The port also supports a considerable fishing industry.
#     4) In 2000, nearly 89% of the city's labor force worked for government-run agencies, institutions, or enterprises. Havana has the country's highest incomes and human development indicators.
#     5) Despite Raul Castro's embrace of free enterprise in 2011, Havana's economy is still in flux, with many small businesses closing due to lack of income from local residents whose salaries average $20 per month.
# 1) Cuba began to attract foreign investment in the 1980s, particularly in hotel development, which led to an increase in tourists from 130,000 to 326,000 by the end of that decade.
# 2) Havana has been a popular health tourism destination for over 20 years, attracting patients from Latin America, Europe, and North America.
# 3) The city suffers from economic deterioration after the collapse of the Soviet Union in 1991, leading to poverty and slums.
# 4) The government does not have an official definition of poverty, but researchers argue that there is a sector of the population at risk or vulnerable using internationally accepted measures.
# 5) Over 9% of Havana's population lives in substandard housing, with the majority concentrated in inner-city neighborhoods such as Old Havana and Centro Habana, as well as shanty towns.
# 1) The Havana suburban railway serves the city, with main stations including Central Rail Station, La Coubre Rail Station, Casablanca Station, and Estación de Túbal.
#     2) In 2004, the annual passenger volume was 11 million, but demand is estimated to be two-and-a-half to three times that value. The busiest route is between Havana and Santiago de Cuba, which is 836 kilometers (519 mi) apart.
#     3) In the 2000s, the Union de Ferrocarriles de Cuba bought French first-class air-conditioned coaches. New Chinese-made and Russian-made coaches for distance trains debuted in the 2010s, some of which now serve suburban services.
#     4) In the 1980s, there were plans for a metro system in Havana similar to Moscow's, but the project was dropped after the fall of the Soviet Union in 1991.
#     5) The city's road network is extensive and includes broad avenues, main streets, and major access roads to the city. However, the network has been under construction and growth since the Spanish era and is undergoing a major deterioration due to low maintenance.
# 1. The National Palace of Havana was built in 1929 as the seat of government and features the third largest indoor statue in the world, the Statue of the Republic.
#     2. El Morro Castle was built in the 16th century to protect the city from pirates, and it still stands today as a symbol of Havana's history and culture.
#     3. The Malecón seaside promenade is a popular spot for sunsets and is lined with historic buildings, including the Hotel Nacional de Cuba, which was once a gambling and entertainment complex.
# ...
#     4. Kuala Lumpur is twinned with several cities around the world, including London, Paris, Tokyo, and Beijing. The city also has a rich history dating back to 1856.
#     5. References: Gullick (1955), Gullick (2000), and the official website of Kuala Lumpur City Hall.
# 1. Kuala Lumpur is a pathfinding challenge in OpenStreetMap due to its complex geography.
#     2. The city has a mix of high-rise buildings, roads, and natural features such as rivers and parks.
#     3. Accurate mapping of the city's geometry is crucial for reliable routing.
#     4. OpenStreetMap (OSM) is a free and open geographic data platform that provides data related to Kuala Lumpur.
#     5. The OSM data can be used to create maps, navigate the city, or perform other geospatial analyses.
#
# ----------------------------------------------
#
# La Paz
#
# Summary: 1. La Paz is a capital city in Bolivia, located in the Amazon basin surrounded by high mountains. It is known as the highest capital city in the world at an elevation of 3650 meters above sea level.
# 2. The city was founded in 1548 by Spanish conquistadors and was originally named "Nuestra Seora de la Paz" (Our Lady of Peace).
# 3. La Paz has a unique subtropical highland climate with rainy summers and dry winters, making it an important cultural center in Latin America.
# 4. The city is home to numerous landmarks from the colonial period, including the San Francisco Church, Metropolitan Cathedral, Plaza Murillo, and Jan Street.
# 5. La Paz is also known for its unique markets, such as the Witches Market, and vibrant nightlife, as well as its unusual topography, which offers stunning views of the city and surrounding mountains from various natural viewing points.
# 1) La Paz, Bolivia was named after the restoration of peace following an insurrection against the first viceroy of Peru, Blasco Nunez Vela.
# 2) In 1825, after a decisive victory in the Spanish American Wars of Independence, the city's full name was changed to "La Paz de Ayacucho" (meaning "The Peace of Ayacucho").
# 3) The region where La Paz is located was known as "Chuquiago Marka" in the Aymara language, leading former President Evo Morales to suggest renaming the city.
# 4) La Paz was founded in 1548 by Alonso de Mendoza with Juan de Vargas appointed as its first mayor. The city's layout was designed by Juan Guterrez Paniagua, expressing the ideals and relationships of Spanish colonial society.
# 5) Indigenous and other unrest occurred around the turn of the 19th century, leading to the legend of the "Ekeko" and a twomonth siege against La Paz in 1809, marking the beginning of the Bolivian War of Independence. Pedro Domingo Murillo was hanged at the Plaza de los Espanoles several months later, and the city's plaza was named after him to commemorate his role in the revolution.
# 1. La Paz is located in the Andes near the eastern split of the Altiplano region, close to notable mountains such as Illimani, Huayna Potosi, Mururata, and Illampu.
# 2. The city's geography is marked by social differences, with affluent residents living in central areas, middle-class residents living in highrise condos near the center, and lower-income residents living in makeshift houses in the surrounding hills.
# 5) La Paz's El Alto International Airport is located 13 km southwest of the city center and at an elevation of 4061 meters (the highest international airport in the world). The airport serves as a hub for Línea de Aviación Caspi and offers flights to cities such as Bogotá, Lima, Santiago, and Cusco.
# 1. La Paz has a complex transportation system with several cable car lines, buses, and taxis.
#     2. The postal service is run by Ecobol, and there are other courier and logistics companies in the city.
#     3. Telecommunications are provided by Entel, and Cotel manages much of the city's phone infrastructure.
#     4. La Paz faces water scarcity due to climate change, which threatens the city's drinking water supply from glaciers and rivers.
#     5. La Paz is a member of several international organizations, including the Union of Iberoamerican Capital Cities and Merco Cities. Notable people from La Paz include politicians, writers, and rally drivers.
#  • Wilfred von Oven (1912-2008) was a press officer at the Reich Propaganda Ministry.
#      • Verona Poth (born 1968) is a German presenter and businesswoman.
#      • Andrés de Santa Cruz (1792-1865) was the President of Peru and Bolivia.
#      • Luis Adolfo Siles Salinas (1925-2005) was a lawyer, politician, and former President of Bolivia.
#      • Gualberto Vega (d. 1980) was a Bolivian trade unionist.
#      • Alberto Villalpando (born 1940) is a composer.
#      • Emilio Villanueva (1882-1970) was an architect.
#
# ----------------------------------------------
#
# Vigan
#
# Summary: 1. Vigan is a 4th class component city and capital of the province of Ilocos Sur in the Philippines.
#     2. According to the 2020 census, the population of Vigan is 539,350 people.
#     3. Vigan is a UNESCO World Heritage Site and one of the few Spanish colonial towns left in the Philippines whose old structures have mostly remained intact.
#     4. The city is known for its unique architecture that fuses Spanish, Filipino, and Oriental designs.
#     5. Vigan was officially recognized as one of the New7Wonders Cities in 2015 together with Beirut, Doha, Durban, Havana, Kuala Lumpur, and La Paz.
# 1. Juan de Salcedo led a expedition to explore the coast of Los Illocanos in 1572 and founded Villa Fernandina de Vigan in honor of King Philip II's son, Prince Ferdinand.
#     2. Salcedo returned to Vigan in 1574 with soldiers and missionaries to pioneer the evangelization of the region. He established a Spanish city for controlling the neighboring country.
#     3. During the Philippine Revolution, revolutionary forces led by Manuel Tinio, supported by Illocano rebels, attacked and defeated the Spanish colonial forces and captured the city in the Siege of Vigan.
#     4. In 1999, UNESCO listed Vigan as the best-preserved example of Spanish colonial towns in Asia, citing its unique blend of Philippine, Chinese, and Spanish cultural elements.
#     5. In 2000, then-President Joseph Estrada signed Republic Act No. 8988, recognizing Vigan's city status granted by a royal decree in 1757. The law took effect in January 2001, without a plebiscite.
# 1. Vigan is situated in a quaternary age sedimentary plain called the Viganbantay Plain, which is part of the Ilocos Coastal Plain.
#     2. The city is divided into 39 barangays, each consisting of puroks and some have sitios.
#     3. Vigan is made up of 60% agricultural land, 32% residential area, nearly 3% commercial and industrial use, and around 1% institutional purpose.
#     4. The city's geologic base and mineral resources include alluvium, fluviatile lacustrine paludal and beach deposits such as coral stones and beach rocks, which are predominantly found along the coastal areas of Vigan.
#     5. The most dominant hill feature in Vigan is the Vigan Gap Hill located in the eastern part, about 10 kilometers away from the city.
# 1. The Viganbantay Plain is characterized by a dissected ridge of Pleistocene age that runs in a northeast-southwest direction, dividing the plain into northern and southern parts.
